# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('usaWild3Month.csv')

# Display the data
df
# Out:
# /var/folders/b2/fg05dp1d0tjgc632gy4vkv4c0000gp/T/ipykernel_76488/3239995426.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#           Id                                           Location  \
# 0       1020      Anniversary Mine Road, Overton, NV 89040, USA
# 1       3548         1701-1749 11th Ave, Seattle, WA 98122, USA
# 2       3903             Robson Ranch Rd, Aguila, AZ 85320, USA
# 3       7842      Cottonwood Springs Road, Indio, CA 92201, USA
# 4       7844             Cascade Rd, Joshua Tree, CA 92252, USA
# ...      ...                                                ...
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Location', 'Name', 'Category', 'Description', 'Latitude',
#        'Longitude', 'Altitude', 'Date verified', 'Open', 'Electricity', 'Wifi',
#        'Kitchen', 'Parking', 'Restaurant', 'Showers', 'Water', 'Toilets',
#        'Big rig friendly', 'Tent friendly', 'Pet friendly',
#        'Sanitation dump station', 'Outdoor gear', 'Groceries', 'Artisan goods',
#        'Bakery', 'Rarity in this area', 'Repairs vehicles',
#        'Repairs motorcycles', 'Repairs bicycles', 'Sells parts',
#        'Recycles batteries', 'Recycles oil', 'Bio fuel',
#        'Electric vehicle charging', 'Composting sawdust', 'Recycling center'],
#       dtype='object')

# %%
new_df = df.loc[:, ['Location', 'Name', 'Description', 'Latitude', 'Longitude', 'Altitude']]
new_df
# Out:
#                                                Location  \
# 0         Anniversary Mine Road, Overton, NV 89040, USA
# 1            1701-1749 11th Ave, Seattle, WA 98122, USA
# 2                Robson Ranch Rd, Aguila, AZ 85320, USA
# 3         Cottonwood Springs Road, Indio, CA 92201, USA
# 4                Cascade Rd, Joshua Tree, CA 92252, USA
# ...                                                 ...
# 1733  Eades Wash River Access, Gila County, Arizona,...
# 1734            Esmeralda County, Nevada, United States
# 1735  US 189, Charleston, Wasatch County, Utah, 8403...
# 1736        I 75, Sumter County, Florida, United States
# 1737  1515, Madison Avenue, Barracks / Rugby, Charlo...
#
#                              Name  \
# 0             Lake Mead RA - NICE
# 1              Cal Anderson Park
# 2       Near Robsons Mining World
# 3           Joshua Tree South BLM
# 4           Joshua Tree North BLM
# ...                           ...
# 1733    Upper Salt River Pull Off
# ...

# %%
new_df.to_csv('usaWild3Month_coords.csv', index=False)

# %%
new_df = new_df.assign(ImageURL='https://example.com/image.jpg')

# %%
df.columns
# Out:
# Index(['Id', 'Location', 'Name', 'Category', 'Description', 'Latitude',
#        'Longitude', 'Altitude', 'Date verified', 'Open', 'Electricity', 'Wifi',
#        'Kitchen', 'Parking', 'Restaurant', 'Showers', 'Water', 'Toilets',
#        'Big rig friendly', 'Tent friendly', 'Pet friendly',
#        'Sanitation dump station', 'Outdoor gear', 'Groceries', 'Artisan goods',
#        'Bakery', 'Rarity in this area', 'Repairs vehicles',
#        'Repairs motorcycles', 'Repairs bicycles', 'Sells parts',
#        'Recycles batteries', 'Recycles oil', 'Bio fuel',
#        'Electric vehicle charging', 'Composting sawdust', 'Recycling center'],
#       dtype='object')

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('usaWild3Month_coords.csv')
# Out:
# /var/folders/b2/fg05dp1d0tjgc632gy4vkv4c0000gp/T/ipykernel_79208/2679124799.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df.columns
# Out:
# Index(['Location', 'Name', 'Description', 'Latitude', 'Longitude', 'Altitude',
#        'Map'],
#       dtype='object')

# %%
df
# Out:
#                                                Location  \
# 0         Anniversary Mine Road, Overton, NV 89040, USA
# 1            1701-1749 11th Ave, Seattle, WA 98122, USA
# 2                Robson Ranch Rd, Aguila, AZ 85320, USA
# 3         Cottonwood Springs Road, Indio, CA 92201, USA
# 4                Cascade Rd, Joshua Tree, CA 92252, USA
# ...                                                 ...
# 1733  Eades Wash River Access, Gila County, Arizona,...
# 1734            Esmeralda County, Nevada, United States
# 1735  US 189, Charleston, Wasatch County, Utah, 8403...
# 1736        I 75, Sumter County, Florida, United States
# 1737  1515, Madison Avenue, Barracks / Rugby, Charlo...
#
#                              Name  \
# 0             Lake Mead RA - NICE
# 1              Cal Anderson Park
# 2       Near Robsons Mining World
# 3           Joshua Tree South BLM
# 4           Joshua Tree North BLM
# ...                           ...
# 1733    Upper Salt River Pull Off
# ...

# %%
ten_site_sample_df = df.sample(n=10)
ten_site_sample_df
# Out:
#                                                Location  \
# 209    Old US 93, Mohave County, Arizona, United States
# 845   2534, Northwest Pettygrove Street, Nob Hill, N...
# 750   County Road A021, Luna County, New Mexico, Uni...
# 936   Kistler Memorial Highway, McDowell County, Nor...
# 1678  Omo Ranch Road, El Dorado County, California, ...
# 485   Ridge Park Road, Newport Coast, Newport Beach,...
# 1562  Old Las Vegas Highway, Santa Fe County, New Me...
# 933          Clark County, Nevada, 89026, United States
# 1481  Riverside Road, Mesquite, Clark County, Nevada...
# 786   4291, Casitas Pass Road, Ventura County, CAL F...
#
#                                           Name  \
# 209                                   Old US93
# 845      Street parking close to Wallance Park
# 750                   Good Site Peak Wild Camp
# 936   Pisgah National Forest Information Cabin
# 1678                        Random forest road
# 485                              Ridge Park Rd
# ...

# %%
ten_site_sample_df.to_csv('usaWild3Month_coords_ten_sample.csv', index=False)
