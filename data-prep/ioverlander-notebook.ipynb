# %%
# !pip -q install langchain openai

# %%
import os

os.environ["OPENAI_API_KEY"] = "" #add key here as env variable

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 0.1.3
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: /Users/marcin.gluc/git/personal/.venv/lib/python3.9/site-packages
# Requires: aiohttp, async-timeout, dataclasses-json, jsonpatch, langchain-community, langchain-core, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:

# %%
import pandas as pd

df = pd.read_csv('usaPlaces2yr.csv')
# Out:
# /var/folders/b2/fg05dp1d0tjgc632gy4vkv4c0000gp/T/ipykernel_26114/4113972567.py:3: DtypeWarning: Columns (13,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('usaPlaces2yr.csv')

# %%
df.head()
# Out:
#      Id                                           Location  \
# 0  1007  Borrego Salton Seaway, Borrego Springs, CA 920...
# 1  1009                Unnamed Road, Austin, NV 89310, USA
# 2  1011              Burr Trail Rd, Boulder, UT 84716, USA
# 3  1014     Coral Pink Sand Dunes Rd, Kanab, UT 84741, USA
# 4  1017               Lincoln Highway, Ruth, NV 89319, USA
#
#                                       Name           Category  \
# 0                      Anza Borrego - NICE       Wild Camping
# 1                     Spencer Hot Springs   Informal Campsite
# 2                        Burr Trail - NICE       Wild Camping
# 3               Coral Pink Sand Dunes - OK       Wild Camping
# 4  Egan Creat Trail System Recreation Area       Wild Camping
#
#                                          Description   Latitude   Longitude  \
# 0  Free Camping on Anza Borrego Park. Nice and wa...  33.280572 -116.146887
# 1  Sweet hot springs with 3 pools. Lots of places...  39.330567 -116.854627
# ...

# %%
from langchain.agents.agent_types import AgentType
from langchain_experimental.agents.agent_toolkits import create_csv_agent
from langchain_openai import ChatOpenAI, OpenAI

# %%
agent = create_csv_agent(
    ChatOpenAI(temperature=0, model="gpt-4"),
    "usaPlaces2yr.csv",
    verbose=True,
    agent_type=AgentType.OPENAI_FUNCTIONS,
)
# Out:
# /Users/marcin.gluc/git/personal/iOverlander/ioverlander-notebook/.venv/lib/python3.11/site-packages/langchain_experimental/agents/agent_toolkits/csv/base.py:28: DtypeWarning: Columns (13,22,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, **_kwargs)

# %%
agent.invoke("how many rows are there?")
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `python_repl_ast` with `{'query': 'df.shape[0]'}`
#
#
# 32988There are 32,988 rows in the dataframe.
#
# > Finished chain.
# {'input': 'how many rows are there?',
#  'output': 'There are 32,988 rows in the dataframe.'}

# %%
agent.invoke("Show me all locations in Chicago and include the category of each location. Only show me sites that are open")
# Out:
# > Entering new AgentExecutor chain...
#
# Invoking: `python_repl_ast` with `{'query': "df[(df['Location'].str.contains('Chicago')) & (df['Open'] == 'Yes')][['Location', 'Category']]"}`
#
#
#                                                 Location  \
# 415                       Moe Dr, Chicago, IL 60616, USA
# 2263   Dazzo's Chicago Style Eatery, 17715, Wickenbur...
# 2393   South Grove Avenue, Chinatown, Armour Square, ...
# 5513   Stockton & Armitage NB, North Stockton Drive, ...
# 5671   2112, West Thomas Street, Ukrainian Village, W...
# 5719   5621, South Kenwood Avenue, University Apartme...
# 6765   Lake Shore Dr & Diversey Pkwy, North Lake Shor...
# 7034   656, North Rockwell Street, Ukrainian Village,...
# 9167   1515, West Berteau Avenue, Lake View, Chicago,...
# 11408  Whitney M. Young Magnet High School, 211, Sout...
# 11832  Chicago and N W Railroad, Ironwood Township, G...
# 11995  Onsted State Game Area, Chicago Road, Cambridg...
# ...
